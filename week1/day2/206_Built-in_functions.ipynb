# %% [markdown]
# + input

# %%
a = input()
# Out:
# 내장함수 알아보기

# %%
print(a)
# Out:
# 내장함수 알아보기

# %%
b = input()
# Out:
# 352

# %%
print('b의 타입은 {}'.format(type(b)))
# Out:
# b의 타입은 <class 'str'>

# %% [markdown]
# + len

# %%
len(a)
# Out:
# 9

# %%
len(b)
# Out:
# 3

# %% [markdown]
# + abs

# %%
c = -32

# %%
c
# Out:
# -32

# %%
abs(c)
# Out:
# 32

# %% [markdown]
# + range

# %%
for x in range(3) :
    print(x+1)
# Out:
# 1
# 2
# 3

# %% [markdown]
# + max / min

# %%
d = [1, 34, 74, 22, 10, 5820, -123, -47]

# %%
max(d)
# Out:
# 5820

# %%
min(d)
# Out:
# -123
