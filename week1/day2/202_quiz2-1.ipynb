# %% [markdown]
# ### 문제 1
# ‘students.txt’ 파일을 읽어서 딕셔너리로 학생들의 정보를 저장하라.
# 해당 파일은 이름, 국어점수, 영어점수, 수학점수 순으로 되어있으며, 각 컬럼의 구분자는 tab(\t)으로 이루어져있다.
# 이름을 key로 하고, 국어점수, 영어점수, 수학점수를 순서대로 담은 리스트를 value로 하는 딕셔너리로 저장하라.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %%
ls -all
# Out:
# total 1
# -rw------- 1 root root 151 May 12 02:37 day2_1.gdoc

# %%
cd txt
# Out:
# /content/drive/My Drive/Colab Notebooks/200406-13/txt

# %%
students = {}

# %%
# 정답을 써주세요

with open('new.txt', 'w') as f :
    data = '국어점수:70\n영어점수:63\n수학점수:99'
    f.write(data)

with open('new.txt', 'r') as f:
    while True :
        line = f.readline()
        if not line : break

        x,y = line.split(':')
        students[x] = int(y)

students
# Out:
# {'국어점수': 70, '수학점수': 99, '영어점수': 63}

# %%
# 주석을 제거하고 출력해보세요
students
# Out:
# {'국어점수': 70, '수학점수': 99, '영어점수': 63}

# %% [markdown]
# ### 문제 2
# 저장한 딕셔너리를 토대로 학생들의 평균을 구하라.
# 전체 학생의 국어, 영어, 수학 점수의 평균을 구해서 각각 kor, eng, math라는 변수에 저장하고, 소수점 첫째자리까지 출력하라.

# %%
kor = students["국어점수"]
eng = students['영어점수']
math = students["수학점수"]

# %%
# 정답을 써주세요

round((kor + eng + math) / 3 , 1)
# Out:
# 77.3

# %%
print('학생들의 평균은 아래와 같습니다.')
print('국어 : %0.1f' %kor)
print('영어 : %0.1f' %eng)
print('수학 : %0.1f' %math)

# %% [markdown]
# ### 문제 3
#
# 학생들 개개인의 평균을 구하는 함수를 작성하라.
# 이름을 넣으면 국어, 영어, 수학 3과목의 평균을 계산하여 반환하는 함수를 작성하라.

# %%
# 정답을 써주세요

# %%
# 만드신 함수로 펭수의 평균을 출력해보세요
