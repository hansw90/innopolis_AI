# %%
import math

# %%
math.factorial(4)
# Out:
# 24

# %%
from math import factorial

# %%
factorial(4)
# Out:
# 24

# %%
import 패키지.모듈
import 패키지.모듈.변수
import 패키지.모듈.함수
import 패키지.모듈.클래스

# %%
from 패키지.모듈 import 변수/함수/클래스
