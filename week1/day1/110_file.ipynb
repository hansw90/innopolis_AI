# %% [markdown]
# # 0. 구글 드라이브 마운트하기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 1. 파일 쓰기
# ### 1-0. 파일?

# %%
# 현재 경로 파악하기
pwd
# Out:
# '/content'

# %% [markdown]
# file name : new.txt
# 상대 경로 : ./toy_data/new.txt
# 절대 경로 : /content/drive/My Drive/Colab Notebooks/python/toy_data/new.txt

# %% [markdown]
# ### 1-1. 파일 쓰기

# %%
new_file = open('/content/drive/My Drive/Colab Notebooks/python/toy_data/new.txt', 'w')

# %%
print(new_file)
# Out:
# <_io.TextIOWrapper name='./drive/My Drive/Colab Notebooks/day2/toy_data/new.txt' mode='w' encoding='UTF-8'>

# %%
data = '새로운 내용을 쓰고 싶다면,\n이렇게 작성하면 됩니다.'

# %%
new_file.write(data)
# Out:
# 29

# %%
new_file.close()

# %% [markdown]
# ### 1-2. with문을 활용하여 파일 쓰기

# %%
with open('/content/drive/My Drive/Colab Notebooks/python/toy_data/new.txt', 'w') as f :
    data = '이렇게도 작성이 가능합니다. close를 따로 안해도 되요.'
    f.write(data)

# %% [markdown]
# # 2. 파일 읽기

# %%
with open('/content/drive/My Drive/Colab Notebooks/python/toy_data/new.txt', 'r') as f:
    lines = f.read()
    print(lines)
    print(type(lines))
# Out:
# 새로운 내용을 쓰고 싶다면,
# 이렇게 작성하면 됩니다.
# <class 'str'>

# %%
with open('/content/drive/My Drive/Colab Notebooks/python/toy_data/new.txt', 'r') as f:
    line = f.readline()
    print(line)
    print(type(lines))
# Out:
# 새로운 내용을 쓰고 싶다면,
#
# <class 'str'>

# %%
with open('/content/drive/My Drive/Colab Notebooks/python/toy_data/new.txt', 'r') as f:
    while True :
        line = f.readline()
        if not line : break
        print(line)
# Out:
# 새로운 내용을 쓰고 싶다면,
#
# 이렇게 작성하면 됩니다.

# %%
with open('/content/drive/My Drive/Colab Notebooks/python/toy_data/new.txt', 'r') as f:
    lines = f.readlines()
    print(lines)
    print(type(lines))
# Out:
# ['새로운 내용을 쓰고 싶다면,\n', '이렇게 작성하면 됩니다.']
# <class 'list'>

# %%
icecream = {"메로나" : [300,20],
            "비비믹" : [400,3],
            "죠스바" : [250,100]
}

# %%
icecream["메로나"]
# Out:
# [300, 20]

# %%
print("%d 원" %icecream["메로나"][0])
# Out:
# 300 원

# %%
print("%d 개" %icecream["메로나"][1])
# Out:
# 20 개

# %%
icecream["월드콘"] = [500,7]

# %%
print(icecream)
# Out:
# {'메로나': [300, 20], '비비믹': [400, 3], '죠스바': [250, 100], '월드콘': [500, 7]}

# %%
icecream.keys()
# Out:
# dict_keys(['메로나', '비비믹', '죠스바', '월드콘'])

# %%
icecream.values()
# Out:
# dict_values([[300, 20], [400, 3], [250, 100], [500, 7]])

# %%
total = 0
for i,j in enumerate(icecream.values()) :
  
  total += j[0]*j[1] 
print("%d 원" %total)
# Out:
# 35700 원
