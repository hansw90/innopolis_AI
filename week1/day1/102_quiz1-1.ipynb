# %% [markdown]
# ### 문제 1
# 10의 제곱을 출력해보자

# %%
# 정답을 적어주세요
10 ** 2
# Out:
# 100

# %% [markdown]
# ### 문제 2
# 2 x 5 + 3 과 2 x (5 + 3)을 각각 화면에 출력해보자

# %%
# 정답을 적어주세요

2 * 5 + 3
# Out:
# 13

# %%
# 정답을 적어주세요

2 * (5+3)
# Out:
# 16
