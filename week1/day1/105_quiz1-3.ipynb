# %% [markdown]
# ### 문제 1
# 좋아하는 음식 5개를 food라는 리스트에 담아보자

# %%
# 정답을 적어주세요
food = ['apple','bannan','orange','melon','mango']

# %% [markdown]
# ### 문제 2
# 리스트 food의 가장 앞에 파이썬이, 가장 뒤에는 집이라는 단어가 오도록 수정해보자

# %%
# 정답을 적어주세요

food[0] = 'python'
food[-1] = 'house'

# %%
# 정답을 적어주세요

food
# Out:
# ['python', 'bannan', 'orange', 'melon', 'house']

# %%
# 아래 주석을 제거하고 food를 출력해보세요
# food

# %% [markdown]
# ### 문제 3
# pop을 이용하여 파이썬을 삭제해보자

# %%
# 정답을 적어주세요

food.pop(0)
food
# Out:
# ['bannan', 'orange']

# %%
# 아래 주석을 제거하고 food를 출력해보세요
# food

# %% [markdown]
# ### 문제 4
# remove를 이용하여 집을 삭제해보자

# %%
# 정답을 적어주세요
food.remove('orange')
food
# Out:
# ['bannan']

# %%
# 아래 주석을 제거하고 food를 출력해보세요
# food

# %% [markdown]
# ### 문제 5
# pop과 remove의 차이점을 몸소 느껴보자

# %% [markdown]
# ### 문제 6
# len( ) 함수를 이용하여 리스트의 길이를 확인해보자

# %%
# 정답을 적어주세요

len(food)
# Out:
# 1

# %% [markdown]
# ### 문제 7
# len( ) 함수를 이용하여 리스트 첫번째 요소의 길이를 확인해보자

# %%
# 정답을 적어주세요
len(food[0])
# Out:
# 6
